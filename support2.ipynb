# %% [markdown]
# Application avec streamlit :

# %% [markdown]
# #### Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
import plotly.express as px

df = pd.read_csv('C:/projet_notebook/ds_salaries.csv')  # Charger un fichier CSV dans un DataFrame

df.head()  # Affiche les 5 premières lignes du DataFrame

df.describe()  #  Résumé statistique des colonnes numériques du DataFrame.

df.groupby('company_size')['salary'].mean()  # Groupement de données par une ou plusieurs colonnes. Moyenne de 'autre_colonne' par 'colonne'
# Out:
# company_size
# L    438794.372247
# M    150712.836029
# S    281430.101351
# Name: salary, dtype: float64

# %% [markdown]
# #### Numpy

# %%
numeric_df = df.select_dtypes(include=[np.number])  # Sélectionner uniquement les colonnes numériques
numeric_df.head(5)
# Out:
#    work_year  salary  salary_in_usd  remote_ratio
# 0       2023   80000          85847           100
# 1       2023   30000          30000           100
# 2       2023   25500          25500           100
# 3       2023  175000         175000           100
# 4       2023  120000         120000           100

# %% [markdown]
# #### Matplotlib
# - (import matplotlib.pyplot as plt)
# - Utilité : matplotlib est une bibliothèque pour créer des visualisations statiques en Python.

# %%
fig, ax = plt.subplots()  #  Crée une figure et un axe pour le graphique

#Créer des graphiques simples en ligne.
#plt.plot(df['work_year'], df['salary'])  # Tracer une courbe avec x et y
plt.plot(df.groupby('work_year')['salary'].mean())  # Tracer une courbe avec x et y

plt.show()  # Affiche le graphique généré

# %% [markdown]
# #### Seaborn
# - (import seaborn as sns)
# - Utilité : seaborn est une bibliothèque de visualisation basée sur matplotlib qui permet de créer des visualisations plus esthétiques et de travailler plus facilement avec des DataFrames.

# %%
#sns.heatmap() : Créer des cartes thermique
correlation_matrix = df[['salary','remote_ratio']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')  # Créer une carte de chaleur pour visualiser la matrice de corrélation
# Out:
# <Axes: >

# %%
# sns.heatmap() : Créer des cartes thermiques.
sns.boxplot(x='work_year', y='salary', data=df)  # Créer un diagramme en boîte pour 'column2' selon 'column1'
# Out:
# <Axes: xlabel='work_year', ylabel='salary'>

# %%
# sns.pairplot() : Créer une matrice de graphiques pour explorer les relations multivariées
sns.pairplot(df)  # Créer un pairplot pour le DataFrame

# %% [markdown]
# #### Streamlit
# - (import streamlit as st)
# - Utilité : streamlit est une bibliothèque pour créer des applications web interactives facilement, principalement pour les projets de data science.

# %%
st.title('Mon Application de Visualisation')  # Affiche un titre
st.write('Texte ou DataFrame à afficher')  # Affiche du texte ou un DataFrame
st.checkbox("Afficher un aperçu des données")  # Afficher une case à cocher pour l'interaction
selected_option = st.selectbox('Choisir une option', options=['Option 1', 'Option 2'])
st.plotly_chart(fig)  # Affiche un graphique interactif Plotly
# Out:
# 2025-02-05 15:00:21.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 15:00:21.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# #### Plotly
# - (import plotly.express as px)
# - Utilité : plotly est une bibliothèque de visualisation interactive qui permet de créer des graphiques interactifs complexes et riches.

# %%
#px.box() : Créer un graphique en boîte interactif
fig = px.box(df, x='job_title', y='salary_in_usd', color='experience_level')  # Créer un boxplot interactif
fig.show()

#px.bar() : Créer un graphique en barres
fig = px.bar(df, x='job_title', y='salary_in_usd', color='company_size')  # Créer un graphique à barres interactif
fig.show()
