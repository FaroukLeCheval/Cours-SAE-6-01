# %%
# pour changer la largeur de la page htlm générée par Jupyter :
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# C:\Users\e2200334\AppData\local\Temp\ipykernel_14392\568132765.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# # TP : Exploration et Analyse de Données avec Pandas et Streamlit
#
# ## Objectif
#
# Ce projet vise à développer vos compétences en manipulation et analyse de données à l'aide de la bibliothèque Pandas en Python. Vous apprendrez à :
#
# - Importer et explorer des données provenant de Kaggle.
# - Effectuer des requêtes et manipulations de type SQL avec Pandas.
# - Créer des visualisations interactives avec Streamlit.
#
# Ce projet est noté. Tous les codes devront être écrits en Python dans des champs *jupyter* et devront respecter les conventions de nommage. L'énoncé **ne doit pas être modifié**.
#
# La derniere séance du projet, vous déposerez le fichier jupyter (projetSAE.ipynb) sur la plateforme pédagogique.

# %% [markdown]
# ##### Procédure à réaliser avant les séances de TD (nous utiliserons désormais jupyter lab)
# - Lancer Anaconda Prompt sous Windows
# - Saisissez dans Anaconda Prompt :
# conda create -n projet python pandas numpy matplotlib jupyterlab kagglehub seaborn streamlit plotly
#
# => à la demande "Proceed ([y]/n)?" saisissez y (ou juste pressez sur la touche "entrée")
# => "Executing transaction" prend du temps, c'est normal
# Saisissez dans Anaconda Prompt :
# conda activate projet
#
# ##### Saisissez dans Anaconda Prompt :
# jupyter lab --notebook-dir="h:/"
# Ouvrir projetSAE.ipynb dans Jupyter

# %%
# %matplotlib notebook
import os
import shutil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import streamlit as st

# %% [markdown]
# ### Partie 1 : importation et exploration des données

# %% [markdown]
# #### Travailler avec Git
# 1 - En utilisant le prompt conda : initialiser le projet
#
# 2 - Ajouter le fichier Jupyter Notebook et faite votre premier commit
#
# 3 -  Creer un projet sur github dépôt distant (sans README.md )
#
# 4 - Pousser le projet vers ce dépôt
#
# 5 - Enlever les checkpoint de jupyter

# %% [markdown]
# #### Questions
# 1. Téléchargez le Dataset **Data Science Salaries 2023** sur Kaggle (https://www.kaggle.com/datasets/) via **kagglehub**.
# 2. Copier le fichier du cache au répertoire du projet, décompresser et visualiser le fichier CSV **ds_salaries.csv**
# 3. Importez le fichiers CSV avec Pandas.

# %% [markdown]
# ##### Votre code

# %%
ds_salaire = pd.read_csv("H:/BUT3/SAE 601/ds_salaries.csv")
ds_salaire
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0       80000             EUR          85847                 ES           100
# 1       30000             USD          30000                 US           100
# 2       25500             USD          25500                 US           100
# 3      175000             USD         175000                 CA           100
# 4      120000             USD         120000                 CA           100
# ...       ...             ...            ...                ...           ...
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 0                  ES            L
# 1                  US            S
# 2                  US            S
# 3                  CA            M
# 4                  CA            M
# ...               ...          ...
# 3750               US            L
# 3751               US            L
# 3752               US            S
# 3753               US            L
# 3754               IN            L
#
# [3755 rows x 11 columns]

# %% [markdown]
# ##### Une bonne pratique
# - Copier les données téléchargées et les coller dans le répertoire du projet.
# Pour cela, utilisez la bibliothéque os et shutil

# %%
# Répertoire cible dans votre projet
project_dir = r"C:/projet_notebook/"

# Créer le répertoire (si nécessaire)
os.makedirs(project_dir, exist_ok=True)

# Copier le fichier depuis le cache au répertoire du projet
cache_file = r"H:/BUT3/SAE 601/ds_salaries.csv"
shutil.copy(cache_file, project_dir)
# Out:
# 'C:/projet_notebook/ds_salaries.csv'

# %%
# Lire le fichier depuis le répertoire du projet
ds_salaire = pd.read_csv("C:/projet_notebook/ds_salaries.csv")
ds_salaire
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0       80000             EUR          85847                 ES           100
# 1       30000             USD          30000                 US           100
# 2       25500             USD          25500                 US           100
# 3      175000             USD         175000                 CA           100
# 4      120000             USD         120000                 CA           100
# ...       ...             ...            ...                ...           ...
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 0                  ES            L
# 1                  US            S
# 2                  US            S
# 3                  CA            M
# 4                  CA            M
# ...               ...          ...
# 3750               US            L
# 3751               US            L
# 3752               US            S
# 3753               US            L
# 3754               IN            L
#
# [3755 rows x 11 columns]

# %% [markdown]
# ### Partie 2 : Analyses exploratoires

# %% [markdown]
# #### Question 1 :
# Nous Souhaitons :
#
# 1. Connaitre est ce qu'il y a des données manquantes dans notre dataset.
# 2. Voir la distribution des salaires en USD avec la bibliothèque seaborn sous fome d'histogramme
# 3. avoir la liste des pays concerné par l'étude
# 4. connaitre les salaire moyen par rôle, par pays, par niveau d'expérience

# %% [markdown]
# #### Votre code

# %%
#données manquantes 
ds_salaire.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# Distribution des salaires en USD
# %matplotlib inline

sns.histplot(ds_salaire['salary_in_usd'], kde=True, bins=30)
plt.title("Distribution des salaires en USD")
plt.xlabel('Salaire (USD)')
plt.ylabel('Fréquence')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# liste des pays concerné par l'étude 
pays = list(pd.unique(ds_salaire['company_location']))
print(pays)
# Out:
# ['ES', 'US', 'CA', 'DE', 'GB', 'NG', 'IN', 'HK', 'NL', 'CH', 'CF', 'FR', 'FI', 'UA', 'IE', 'IL', 'GH', 'CO', 'SG', 'AU', 'SE', 'SI', 'MX', 'BR', 'PT', 'RU', 'TH', 'HR', 'VN', 'EE', 'AM', 'BA', 'KE', 'GR', 'MK', 'LV', 'RO', 'PK', 'IT', 'MA', 'PL', 'AL', 'AR', 'LT', 'AS', 'CR', 'IR', 'BS', 'HU', 'AT', 'SK', 'CZ', 'TR', 'PR', 'DK', 'BO', 'PH', 'BE', 'ID', 'EG', 'AE', 'LU', 'MY', 'HN', 'JP', 'DZ', 'IQ', 'CN', 'NZ', 'CL', 'MD', 'MT']

# %%
#Salaire moyen par rôle
ds_salaire.groupby(by=['job_title'])['salary'].mean().round(3)
# Out:
# job_title
# 3D Computer Vision Researcher    120000.000
# AI Developer                     137181.818
# AI Programmer                     55000.000
# AI Scientist                     275312.500
# Analytics Engineer               151352.621
#                                     ...
# Research Engineer                162752.811
# Research Scientist               160768.890
# Software Data Engineer            75000.000
# Staff Data Analyst                15000.000
# Staff Data Scientist             105000.000
# Name: salary, Length: 93, dtype: float64

# %%
# Salaire moyen par pays
ds_salaire.groupby(by=['employee_residence'])['salary'].mean().round(3)
# Out:
# employee_residence
# AE    100000.000
# AM     50000.000
# AR     35500.000
# AS     32777.500
# AT     65833.333
#          ...
# TR    114600.000
# UA     57850.000
# US    152822.012
# UZ    103000.000
# VN     33466.667
# Name: salary, Length: 78, dtype: float64

# %%
# Salaires moyens par niveau d'expérience
ds_salaire.groupby(by=['experience_level'])['salary'].mean().round(5)
# Out:
# experience_level
# EN    188381.17812
# EX    246802.20175
# MI    248200.30683
# SE    170048.96542
# Name: salary, dtype: float64

# %% [markdown]
# #### Question 2 :
# Nous Souhaitons :
#
# 1. Filtrer les salaires pour un pays donné (ex : US)
# 2. Connaitre les top 5 des entreprises qui paient le plus
#
# 3. Filtrage et agrégation:
#     - Afficher tous les employés dont le salaire est supérieur à 100 000 USD, ainsi que leur rôle.
#     - Pays avec la plus forte proportion de télétravail (remote_ratio = 100)
#
# 4. Requêtes conditionnelles:
#     - Salaire moyen des employés à distance (100%)
#     - Comparer salaires moyens pour deux catégories
#
# 5. Ajouter une colonne pour les fourchettes de salaires
# 6. Corrélations : Relation entre télétravail et salaire:
#  -
# 7. Salaire moyen par taille d'entreprise
# 8. faire un tableau croisé : Moyenne des salaires par niveau d'expérience et télétravail

# %%
# Filtrer les salaires pour un pays donné (ex : US)
ds_salaire.where(ds_salaire['company_location']=='US').dropna()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 1        2023.0               MI              CT               ML Engineer
# 2        2023.0               MI              CT               ML Engineer
# 5        2023.0               SE              FT         Applied Scientist
# 6        2023.0               SE              FT         Applied Scientist
# 9        2023.0               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3749     2021.0               SE              FT           Data Specialist
# 3750     2020.0               SE              FT            Data Scientist
# 3751     2021.0               MI              FT  Principal Data Scientist
# 3752     2020.0               EN              FT            Data Scientist
# 3753     2020.0               EN              CT     Business Data Analyst
#
#         salary salary_currency  salary_in_usd employee_residence  \
# 1      30000.0             USD        30000.0                 US
# 2      25500.0             USD        25500.0                 US
# 5     222200.0             USD       222200.0                 US
# 6     136000.0             USD       136000.0                 US
# 9     147100.0             USD       147100.0                 US
# ...        ...             ...            ...                ...
# 3749  165000.0             USD       165000.0                 US
# 3750  412000.0             USD       412000.0                 US
# 3751  151000.0             USD       151000.0                 US
# 3752  105000.0             USD       105000.0                 US
# 3753  100000.0             USD       100000.0                 US
#
#       remote_ratio company_location company_size
# 1            100.0               US            S
# 2            100.0               US            S
# 5              0.0               US            L
# 6              0.0               US            L
# 9              0.0               US            M
# ...            ...              ...          ...
# 3749         100.0               US            L
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
#
# [3040 rows x 11 columns]

# %%
# Top 5 des entreprises qui paient le plus
ds_salaire.groupby(by=['company_location']).mean(['salary']).sort_values(by=['salary'], ascending=False).head(5).round(2)
# Out:
#                   work_year       salary  salary_in_usd  remote_ratio
# company_location
# CL                  2021.00  30400000.00       40038.00        100.00
# HU                  2021.00   8800000.00       26709.50         75.00
# JP                  2020.67   3408666.67      114127.33         41.67
# ID                  2022.00   2107500.00       34208.00         50.00
# IN                  2021.66   1814034.43       30197.74         68.97

# %%
# Rôles avec un salaire moyen supérieur à 100,000
tmp = ds_salaire.groupby(by=['job_title']).mean(['salary']).round(2).sort_values(by=['salary'], ascending=True)
resu = tmp.where(tmp['salary']>100000).dropna()
resu['salary']
# Out:
# job_title
# Financial Data Analyst             101666.67
# BI Analyst                         104888.89
# Staff Data Scientist               105000.00
# Deep Learning Engineer             105000.00
# Machine Learning Researcher        111166.67
#                                      ...
# Data Analytics Lead                922500.00
# Lead Data Scientist                928485.33
# Lead Machine Learning Engineer    2548666.67
# Principal Data Architect          3000000.00
# Head of Machine Learning          6000000.00
# Name: salary, Length: 67, dtype: float64

# %%
# Pays avec la plus forte proportion de télétravail (remote_ratio = 100)
df_temp_prop = ds_salaire[ds_salaire['remote_ratio'] == 100].groupby('employee_residence')['remote_ratio'].count()
df_temp_prop = df_temp_prop.sort_values(ascending=False)
print(df_temp_prop)
# Out:
# employee_residence
# US    1302
# GB      61
# CA      45
# IN      39
# ES      25
# DE      17
# BR      16
# FR      15
# GR      12
# MX       9
# PT       8
# NL       8
# AR       6
# PL       6
# AU       6
# PK       5
# NG       5
# PR       4
# IE       3
# IT       3
# SI       3
# BE       3
# PH       2
# JP       2
# RU       2
# KE       2
# SG       2
# AE       2
# VN       2
# CF       2
# CL       2
# CH       2
# BO       2
# SE       1
# UZ       1
# AT       1
# UA       1
# TR       1
# TN       1
# TH       1
# SK       1
# BG       1
# HU       1
# LU       1
# RS       1
# CO       1
# CZ       1
# DO       1
# EE       1
# EG       1
# MY       1
# HR       1
# IR       1
# Name: remote_ratio, dtype: int64

# %%
# Requêtes conditionnelles
# Salaire moyen des employés à distance (100%)
ds_sal_dist = ds_salaire[ds_salaire['remote_ratio'] == 100]
sal_dist = ds_sal_dist['salary'].mean().round(3)
# Comparer salaires moyens pour deux catégories
ds_sal_ndist = ds_salaire[ds_salaire['remote_ratio'] != 100]
sal_ndist = ds_sal_ndist['salary'].mean().round(3)

print("Différence entre salaire full distanciel et les autres (Distanciel - Non-distanciel) :", sal_dist - sal_ndist)
# Out:
# Différence entre salaire full distanciel et les autres (Distanciel - Non-distanciel) : 625.19200000001

# %%
# Ajouter une colonne pour les fourchettes de salaires
ds_salaire['range_salary'] = pd.cut(ds_salaire['salary'], 
                                    bins=[0,50000,100000,150000, float("inf")],
                                    labels=["<50k", "50k-100k", "100k-150k", "+150k"])
       

ds_salaire
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0       80000             EUR          85847                 ES           100
# 1       30000             USD          30000                 US           100
# 2       25500             USD          25500                 US           100
# 3      175000             USD         175000                 CA           100
# 4      120000             USD         120000                 CA           100
# ...       ...             ...            ...                ...           ...
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size range_salary
# 0                  ES            L     50k-100k
# 1                  US            S         <50k
# 2                  US            S         <50k
# 3                  CA            M        +150k
# 4                  CA            M    100k-150k
# ...               ...          ...          ...
# 3750               US            L        +150k
# 3751               US            L        +150k
# 3752               US            S    100k-150k
# 3753               US            L     50k-100k
# 3754               IN            L        +150k
#
# [3755 rows x 12 columns]

# %%
# Analyse des corrélations
# Relation entre télétravail et salaire
ds_salaire[['salary','remote_ratio']].corr()
# Out:
#                 salary  remote_ratio
# salary        1.000000      0.028731
# remote_ratio  0.028731      1.000000

# %%
# Salaire moyen par taille d'entreprise
ds_salaire.groupby(by=['company_size'])['salary'].mean().round(5)
# Out:
# company_size
# L    438794.37225
# M    150712.83603
# S    281430.10135
# Name: salary, dtype: float64

# %%
# Tableaux croisés
# Moyenne des salaires par niveau d'expérience et télétravail
pivot_table = ds_salaire.pivot_table(
    index=['experience_level'], 
    columns=['remote_ratio'], 
    values=['salary'], 
    aggfunc='mean'
)
print("Tableau croisé des salaires :", pivot_table)
# Out:
# Tableau croisé des salaires :                          salary
# remote_ratio                0             50             100
# experience_level
# EN                119080.801802  2.005770e+05  236295.138889
# EX                181063.214286  1.137333e+06  214844.442308
# MI                134881.055556  7.933464e+05  261733.489552
# SE                161849.367647  6.071959e+05  162780.069245
